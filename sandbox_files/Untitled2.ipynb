# %%
from iex import Stock, reference
import iexfinance
from iexfinance.stocks import get_historical_data
from datetime import datetime
from time import sleep
import pandas as pd
import os

from pandas_datareader import data as pdr
import fix_yahoo_finance as yf

yf.pdr_override()

# %%
aapl = Stock('AAPL')

# %%
aapl.book()

# %%
aapl.chart_table()
# Out:
# https://api.iextrading.com/1.0/stock/AAPL/chart/1m
#     change  changeOverTime  changePercent   close        date     high  \
# 0    -0.32        0.000000         -0.182  175.53  2019-03-05  176.000
# 1    -1.01       -0.005754         -0.575  174.52  2019-03-06  175.490
# 2    -2.02       -0.017262         -1.157  172.50  2019-03-07  174.440
# 3     0.41       -0.014926          0.238  172.91  2019-03-08  173.070
# 4     5.99        0.019199          3.464  178.90  2019-03-11  179.120
# 5     2.01        0.030650          1.124  180.91  2019-03-12  182.670
# 6     0.80        0.035208          0.442  181.71  2019-03-13  183.300
# 7     2.02        0.046716          1.112  183.73  2019-03-14  184.100
# 8     2.39        0.060332          1.301  186.12  2019-03-15  187.330
# 9     1.90        0.071156          1.021  188.02  2019-03-18  188.390
# 10   -1.49        0.062667         -0.792  186.53  2019-03-19  188.990
# ...

# %%
aapl.financials_table()
# Out:
# https://api.iextrading.com/1.0/stock/AAPL/financials
#     cashChange     cashFlow  costOfRevenue  currentAssets  currentCash  \
# 0  18858000000  26690000000    52279000000   140828000000  44771000000
# 1  -6058000000  19523000000    38816000000   131339000000  25913000000
# 2 -13088000000  14488000000    32844000000   115761000000  31971000000
# 3  17568000000  15130000000    37715000000   130053000000  45059000000
#
#    currentDebt  grossProfit    netIncome  operatingExpense  \
# 0  21741000000  32031000000  19965000000        8685000000
# 1  20748000000  24084000000  14125000000        7966000000
# 2  17472000000  20421000000  11519000000        7809000000
# 3  20478000000  23422000000  13822000000        7528000000
#
#   operatingGainsLosses  operatingIncome  operatingRevenue  reportDate  \
# 0                 None      23346000000       84310000000  2018-12-31
# 1                 None      16118000000       62900000000  2018-09-30
# ...

# %%
aapl.news()
# Out:
# https://api.iextrading.com/1.0/stock/AAPL/news/last/10
# [{'datetime': '2019-04-07T22:06:48-04:00',
#   'headline': 'A Fat Bear Floating On A Sea Of Liquidity: Q1 Review And Q2 Outlook',
#   'source': 'SeekingAlpha',
#   'url': 'https://api.iextrading.com/1.0/stock/aapl/article/6327615471203586',
#   'summary': '    Navel-gazing in a sea of liquidity.  PixaBay .      A Quarter  of  Wrong     Well. That was something.    Data by YCharts    But, more to the point, just last quarter:    Data by YCharts    While not the Q1 rally we saw in Chinese equities, the Feds double-reversal and continued trade…',
#   'related': 'AAPL,BK,C,Computer Hardware,CON31167138,FDX,FTAI,NASDAQ01,SPXU,Computing and Information Technology,UVXY',
#   'image': 'https://api.iextrading.com/1.0/stock/aapl/news-image/6327615471203586'}]

# %%
aapl.ohlc()
# Out:
# https://api.iextrading.com/1.0/stock/AAPL/ohlc
# {'open': {'price': 196.41, 'time': 1554471000561},
#  'close': {'price': 197, 'time': 1554494400394},
#  'high': 197.1,
#  'low': 195.93}

# %%
aapl.relevant()
# Out:
# https://api.iextrading.com/1.0/stock/AAPL/relevant
# {'peers': True, 'symbols': ['MSFT', 'NOK', 'IBM', 'HPQ', 'GOOGL', 'BB', 'XLK']}

# %%
aapl.splits()
# Out:
# https://api.iextrading.com/1.0/stock/AAPL/splits/1m
# []

# %%
aapl.stats()
# Out:
# https://api.iextrading.com/1.0/stock/AAPL/stats
# {'companyName': 'Apple Inc.',
#  'marketcap': 928910160000,
#  'beta': 1.138085,
#  'week52high': 233.47,
#  'week52low': 142,
#  'week52change': 15.740601,
#  'shortInterest': 0,
#  'shortDate': 0,
#  'dividendRate': 2.92,
#  'dividendYield': 1.4822335,
#  'exDividendDate': '2019-02-08 00:00:00.0',
#  'latestEPS': 11.88,
#  'latestEPSDate': '2018-09-30',
#  'sharesOutstanding': 4715280000,
#  'float': 4705480460,
#  'returnOnEquity': 47.15,
#  'consensusEPS': 4.17,
#  'numberOfEstimates': 11,
#  'EPSSurpriseDollar': None,
#  'EPSSurprisePercent': 0.2398,
#  'symbol': 'AAPL',
#  'EBITDA': 0,
#  'revenue': 0,
#  'grossProfit': 0,
#  'cash': 0,
#  'debt': 0,
#  'ttmEPS': 12.16,
#  'revenuePerShare': 0,
#  'revenuePerEmployee': 0,
#  'peRatioHigh': 0,
#  'peRatioLow': 0,
#  'returnOnAssets': 15.58,
#  'returnOnCapital': None,
#  'profitMargin': 22.75,
#  'priceToSales': 4.602734,
#  'priceToBook': None,
#  'day200MovingAvg': 189.84975,
# ...

# %%
aapl.time_series()
# Out:
# https://api.iextrading.com/1.0/stock/AAPL/chart/1m
# [{'date': '2019-03-08',
#   'open': 170.32,
#   'high': 173.07,
#   'low': 169.5,
#   'close': 172.91,
#   'volume': 23999358,
#   'unadjustedVolume': 23999358,
#   'change': 0.41,
#   'changePercent': 0.238,
#   'vwap': 171.8064,
#   'label': 'Mar 8',
#   'changeOverTime': 0},
#  {'date': '2019-03-11',
#   'open': 175.49,
#   'high': 179.12,
#   'low': 175.35,
#   'close': 178.9,
#   'volume': 32011034,
#   'unadjustedVolume': 32011034,
#   'change': 5.99,
#   'changePercent': 3.464,
#   'vwap': 178.1174,
#   'label': 'Mar 11',
#   'changeOverTime': 0.034642299462147995},
#  {'date': '2019-03-12',
#   'open': 180,
#   'high': 182.67,
#   'low': 179.37,
#   'close': 180.91,
#   'volume': 32467584,
#   'unadjustedVolume': 32467584,
#   'change': 2.01,
#   'changePercent': 1.124,
#   'vwap': 181.1313,
#   'label': 'Mar 12',
#   'changeOverTime': 0.04626684402290209},
#  {'date': '2019-03-13',
#   'open': 182.25,
#   'high': 183.3,
# ...

# %%
aapl = iexfinance.stocks.Stock("AAPL")

# %%
aapl.get_financials()
# Out:
# [{'reportDate': '2018-12-31',
#   'grossProfit': 32031000000,
#   'costOfRevenue': 52279000000,
#   'operatingRevenue': 84310000000,
#   'totalRevenue': 84310000000,
#   'operatingIncome': 23346000000,
#   'netIncome': 19965000000,
#   'researchAndDevelopment': 3902000000,
#   'operatingExpense': 8685000000,
#   'currentAssets': 140828000000,
#   'totalAssets': 373719000000,
#   'totalLiabilities': 255827000000,
#   'currentCash': 44771000000,
#   'currentDebt': 21741000000,
#   'totalCash': 86427000000,
#   'totalDebt': 114730000000,
#   'shareholderEquity': 117892000000,
#   'cashChange': 18858000000,
#   'cashFlow': 26690000000,
#   'operatingGainsLosses': None},
#  {'reportDate': '2018-09-30',
#   'grossProfit': 24084000000,
#   'costOfRevenue': 38816000000,
#   'operatingRevenue': 62900000000,
#   'totalRevenue': 62900000000,
#   'operatingIncome': 16118000000,
#   'netIncome': 14125000000,
#   'researchAndDevelopment': 3750000000,
#   'operatingExpense': 7966000000,
# ...

# %%
aapl.get_key_stats()
# Out:
# {'companyName': 'Apple Inc.',
#  'marketcap': 928910160000,
#  'beta': 1.138085,
#  'week52high': 233.47,
#  'week52low': 142,
#  'week52change': 15.740601,
#  'shortInterest': 0,
#  'shortDate': 0,
#  'dividendRate': 2.92,
#  'dividendYield': 1.4822335,
#  'exDividendDate': '2019-02-08 00:00:00.0',
#  'latestEPS': 11.88,
#  'latestEPSDate': '2018-09-30',
#  'sharesOutstanding': 4715280000,
#  'float': 4705480460,
#  'returnOnEquity': 47.15,
#  'consensusEPS': 4.17,
#  'numberOfEstimates': 11,
#  'EPSSurpriseDollar': None,
#  'EPSSurprisePercent': 0.2398,
#  'symbol': 'AAPL',
#  'EBITDA': 0,
#  'revenue': 0,
#  'grossProfit': 0,
#  'cash': 0,
#  'debt': 0,
#  'ttmEPS': 12.16,
#  'revenuePerShare': 0,
#  'revenuePerEmployee': 0,
#  'peRatioHigh': 0,
#  'peRatioLow': 0,
#  'returnOnAssets': 15.58,
#  'returnOnCapital': None,
#  'profitMargin': 22.75,
#  'priceToSales': 4.602734,
#  'priceToBook': None,
#  'day200MovingAvg': 189.84975,
#  'day50MovingAvg': 177.57301,
# ...

# %%
from iexfinance.stocks import get_market_gainers
get_market_gainers()
# Out:
# [{'symbol': 'WINS',
#   'companyName': 'Wins Finance Holdings Inc.',
#   'primaryExchange': 'NASDAQ Capital Market',
#   'sector': 'Financial Services',
#   'calculationPrice': 'close',
#   'open': 23.6,
#   'openTime': 1554471120278,
#   'close': 24.28,
#   'closeTime': 1554494400313,
#   'high': 24.3,
#   'low': 24,
#   'latestPrice': 24.28,
#   'latestSource': 'Close',
#   'latestTime': 'April 5, 2019',
#   'latestUpdate': 1554494400313,
#   'latestVolume': 850,
#   'iexRealtimePrice': None,
#   'iexRealtimeSize': None,
#   'iexLastUpdated': None,
#   'delayedPrice': 24.28,
#   'delayedPriceTime': 1554494400313,
#   'extendedPrice': 27.01,
#   'extendedChange': 2.73,
#   'extendedChangePercent': 0.11244,
#   'extendedPriceTime': 1553693302318,
#   'previousClose': 23.62,
#   'change': 0.66,
#   'changePercent': 0.02794,
#   'iexMarketPercent': None,
#   'iexVolume': None,
#   'avgTotalVolume': 3603,
#   'iexBidPrice': None,
#   'iexBidSize': None,
#   'iexAskPrice': None,
# ...

# %%
from iexfinance import iexdata

iexdata.get_tops('AAPL')
# Out:
# []

# %% [markdown]
# # Filling data for each Stock

# %%
companies = reference.symbols()
symbols = companies['symbol']

# %%
symbol = symbols[0]

# %%
import json
import urllib

api_key = "AIzaSyA3_hakldxZnSU-VCiRgQSKNKbM7cUU0ik"
query = 'Taylor Swift'
service_url = 'https://kgsearch.googleapis.com/v1/entities:search'
params = {
    'query': query,
    'limit': 10,
    'indent': True,
    'key': api_key,
}
url = service_url + '?' + urllib.parse.urlencode(params)
response = json.loads(urllib.request.urlopen(url).read())
for element in response['itemListElement']:
  print (element['result']['name'] + ' (' + str(element['resultScore']) + ')')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-55-2d82cc7a2382> in <module>
#      12 }
#      13 url = service_url + '?' + urllib.parse.urlencode(params)
# ---> 14 response = json.loads(urllib.request.urlopen(url).read())
#      15 for element in response['itemListElement']:
#      16   print (element['result']['name'] + ' (' + str(element['resultScore']) + ')')
#
# ~/anaconda2/envs/py3/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~/anaconda2/envs/py3/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
# ...
